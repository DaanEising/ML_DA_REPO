# %%
# !pip install git+https://github.com/psf/requests-html.git#egg=requests-html
# %reset
import httpx
import re
import requests
import codecs
import time
import nltk

import threading
import pandas as pd

from bs4 import BeautifulSoup as bs

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options

from sklearn.preprocessing import MinMaxScaler
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
HEADERS = {'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
           'Accept-Encoding': 'gzip, deflate, br',
           'Accept-Language': 'en-US,en;q=0.9,nl;q=0.8',
           'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36'
          }

YAHOO_CONSENT_COOKIES = None

DATA_LOCATION = 'Datasets/'

HOMEPAGE_URL = 'https://www.investopedia.com/markets-news-4427704'

VUSA_DOWNLOAD_URL = 'https://datahub.io/core/s-and-p-500-companies'
SP_DOWNLOAD_URL = 'https://datahub.io/core/s-and-p-500'
DATAHUB_URL = 'https://datahub.io'


YAHOO_URL = 'https://finance.yahoo.com/'

nltk.download(['punkt', 'wordnet', 'stopwords', 'omw-1.4', 'vader_lexicon'])
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Mark\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Mark\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Mark\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Mark\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Mark\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
options = Options()
options.add_argument('--headless')
options.add_argument('--disable-gpu')

# %%
def get_yahoo_cookies():
    yahoo_cookie_driver = webdriver.Chrome(options=options)
    yahoo_cookie_driver.get(YAHOO_URL)
    time.sleep(2)
    yahoo_cookie_driver.find_element(By.CLASS_NAME, 'reject-all').click()
    time.sleep(2)
    all_cookies=yahoo_cookie_driver.get_cookies();
    cookies_dict = {}
    for cookie in all_cookies:
        cookies_dict[cookie['name']] = cookie['value']
    cookies = [{'name': cookie[0], 'value': cookie[1]} for cookie in cookies_dict.items()]
    return cookies

# %%
YAHOO_CONSENT_COOKIES = get_yahoo_cookies()

# %%
def get_response(url, cookies={}, headers=HEADERS):
    r = httpx.get(url, cookies=cookies, headers=headers, follow_redirects=True)
    soup = bs(r.content)
    return soup

# %%
soup = get_response(HOMEPAGE_URL, HEADERS)

# %%
def get_card_titles():
    titles = []
    a_tags = soup.find_all('a', class_='card')
    for i in range(len(a_tags)):
        titles.append(a_tags[i].span.text)
    return titles

def get_card_urls():
    urls = []
    a_tags = soup.find_all('a', class_='card')
    for i in range(len(a_tags)):
        urls.append(a_tags[i]['href'])
    return urls

# %%
titles = get_card_titles()
urls = get_card_urls()

# %%
investopedia_df = pd.DataFrame({'url': urls, 'title': titles})
display(investopedia_df)
# Out:
#                                                   url  \
# 0   https://www.investopedia.com/what-to-expect-in...
# 1   https://www.investopedia.com/s-and-p-500-gains...
# 2   https://www.investopedia.com/fake-sec-social-m...
# 3   https://www.investopedia.com/midday-movers-oil...
# 4   https://www.investopedia.com/3-charts-for-inve...
# ..                                                ...
# 60  https://www.investopedia.com/3-charts-for-inve...
# 61  https://www.investopedia.com/5-things-to-know-...
# 62  https://www.investopedia.com/s-and-p-500-gains...
# 63  https://www.investopedia.com/crypto-related-sh...
# 64  https://www.investopedia.com/midday-movers-tes...
#
#                                                 title
# 0             What To Expect in the Markets This Week
# 1   S&P 500 Gains and Losses Today: Airline Stocks...
# 2   Fake SEC Social Media Post Puts Security Pract...
# 3   Midday Movers: Oil Jumps, Hitting Airline Stoc...
# 4   3 Charts For Investors to Watch Friday: DocuSi...
# ..                                                ...
# 60  3 Charts For Investors to Watch Thursday: GC E...
# 61     5 Things to Know Before The Stock Market Opens
# 62  S&P 500 Gains and Losses: An Update to the Mod...
# 63  Crypto-Related Company Stocks Jump as Digital ...
# 64  Midday Movers: Tesla's Revamped Model Y, Strea...
#
# [65 rows x 2 columns]

# %%
def clean_text(text):
    return re.sub(r'[^\w\s]', '', text)

# %%
def get_url_content(urls):
    articles = []
    raw_articles = []
    for url in urls:
        soup = get_response(url)
        paragraphs = soup.find('div', class_='article-content').find_all('p')
        article = ''.join([p.get_text(separator=' ') for p in paragraphs])
        
        raw_articles.append(paragraphs)
        articles.append(clean_text(article))
    return articles, raw_articles

def get_symbols(raw_articles, href_ref):
    symbol_list = []
    for p_list in raw_articles:
        article_symbols = []
        for p in p_list:
            symbols = [a_tag.text for a_tag in p.find_all('a') if re.search(href_ref, a_tag['href'])]
            if symbols:
                for symbol in symbols:
                    article_symbols.append(symbol)
        symbol_list.append(article_symbols)
    return symbol_list

# %%
articles, raw_articles = get_url_content(investopedia_df['url'])

# %%
investopedia_df['article'] = articles

# %%
symbols = get_symbols(raw_articles, 'widgetsymbol')

# %%
investopedia_df['symbols'] = symbols

# %%
display(investopedia_df)
# Out:
#                                                   url  \
# 0   https://www.investopedia.com/what-to-expect-in...
# 1   https://www.investopedia.com/s-and-p-500-gains...
# 2   https://www.investopedia.com/fake-sec-social-m...
# 3   https://www.investopedia.com/midday-movers-oil...
# 4   https://www.investopedia.com/3-charts-for-inve...
# ..                                                ...
# 60  https://www.investopedia.com/3-charts-for-inve...
# 61  https://www.investopedia.com/5-things-to-know-...
# 62  https://www.investopedia.com/s-and-p-500-gains...
# 63  https://www.investopedia.com/crypto-related-sh...
# 64  https://www.investopedia.com/midday-movers-tes...
#
#                                                 title  \
# 0             What To Expect in the Markets This Week
# 1   S&P 500 Gains and Losses Today: Airline Stocks...
# 2   Fake SEC Social Media Post Puts Security Pract...
# 3   Midday Movers: Oil Jumps, Hitting Airline Stoc...
# 4   3 Charts For Investors to Watch Friday: DocuSi...
# ..                                                ...
# 60  3 Charts For Investors to Watch Thursday: GC E...
# 61     5 Things to Know Before The Stock Market Opens
# 62  S&P 500 Gains and Losses: An Update to the Mod...
# 63  Crypto-Related Company Stocks Jump as Digital ...
# 64  Midday Movers: Tesla's Revamped Model Y, Strea...
#
#                                               article  \
# 0   \nMarkets are closed on Monday Jan 15 for Mart...
# 1   \nUS equities were mixed as earnings season go...
# 2   \nThe hack this week of the Securities and Exc...
# 3   \nUS equities were little changed at midday as...
# 4   \nHeres our daily look at three charts connect...
# ..                                                ...
# 60  \nHeres our daily look at three charts connect...
# 61  \nApple resumed sales of watches after an appe...
# 62  \nIt wasnt much but US equities kept their ral...
# 63  \nStocks related to the cryptocurrency industr...
# 64  \nUS equities were little changed at midday as...
#
#                                               symbols
# 0   [MS, GS, MS, GS, SCHW, DFS, MTB, FITB, STT, WF...
# 1        [CTSH, DAL, UAL, AAL, TSLA, HTZ, WRL, ELUXY]
# 2                                               [SWI]
# 3                [DAL, UNH, CVS, TGT, BK, T, VZ, NOC]
# 4                           [DOCU, BX, HTZ, TSLA, MS]
# ..                                                ...
# 60                                       [LOPE, IOVA]
# 61                      [AAPL, SQM, TSLA, SATS, DISH]
# 62  [KMX, MRNA, TSLA, NWSA, MSFT, NEM, LVS, DIS, A...
# 63                           [COIN, MARA, RIOT, MSTR]
# 64     [TSLA, NWSA, MSFT, NEM, AAPL, PARA, DIS, AMZN]
#
# [65 rows x 4 columns]

# %%
def get_datahub_csv(URL, filename):
    soup = get_response(URL)
    download_url = soup.find_all('table')[1].find_all('a')[1]['href']
    download_url = DATAHUB_URL + download_url
    with open(DATA_LOCATION + filename, 'wb') as f:
        f.write(requests.get(download_url).content)

# %%
get_datahub_csv(VUSA_DOWNLOAD_URL, 'vusa_holdings.csv')
get_datahub_csv(SP_DOWNLOAD_URL, 'time_data.csv')

# %%
vusa_df = pd.read_csv(DATA_LOCATION + 'vusa_holdings.csv')
symbols_in_vusa = vusa_df['Symbol'].tolist()

# %%
investopedia_df['appears_in_vusa'] = investopedia_df['symbols'].apply(lambda symbols: any(symbol in symbols_in_vusa for symbol in symbols))
investopedia_df = investopedia_df[investopedia_df['appears_in_vusa']]
# Out:
#                                                   url  \
# 0   https://www.investopedia.com/what-to-expect-in...
# 1   https://www.investopedia.com/s-and-p-500-gains...
# 3   https://www.investopedia.com/midday-movers-oil...
# 4   https://www.investopedia.com/3-charts-for-inve...
# 5   https://www.investopedia.com/dow-jones-today-0...
# 6   https://www.investopedia.com/5-things-to-know-...
# 7   https://www.investopedia.com/s-and-p-500-gains...
# 8   https://www.investopedia.com/midday-movers-net...
# 9   https://www.investopedia.com/dow-jones-today-0...
# 10  https://www.investopedia.com/3-charts-for-inve...
# 11  https://www.investopedia.com/5-things-to-know-...
# 12  https://www.investopedia.com/s-and-p-500-gains...
# 13  https://www.investopedia.com/midday-movers-int...
# 14  https://www.investopedia.com/3-charts-for-inve...
# 15  https://www.investopedia.com/dow-jones-today-0...
# 16  https://www.investopedia.com/5-things-to-know-...
# 17  https://www.investopedia.com/s-and-p-500-gains...
# 18  https://www.investopedia.com/midday-movers-boe...
# 19  https://www.investopedia.com/3-charts-for-inve...
# 20  https://www.investopedia.com/dow-jones-today-0...
# 21  https://www.investopedia.com/5-things-to-know-...
# 22  https://www.investopedia.com/s-and-p-500-gains...
# 23  https://www.investopedia.com/midday-movers-nvi...
# 24  https://www.investopedia.com/3-charts-for-inve...
# 25  https://www.investopedia.com/dow-jones-today-0...
# 26  https://www.investopedia.com/5-things-to-know-...
# 17  \nThe SP 500 fell 02 on Tuesday as Mondays tec...
# 18  \nUS equities reversed Mondays gains and were ...
# 19  \nHeres our daily look at three charts linked ...
# 20  \nStocks recovered somewhat from early losses ...
# 21  \nBoeing shares extended losses as airline ins...
# 22  \nThe major US equity indexes pushed higher on...
# 23  \nThe SP 500 and Nasdaq advanced at midday lif...
# 24  \nHeres our daily look at three charts tied to...
# 25  \n UpdateJan 9 2024  For todays live markets c...
# 26  \nBoeing shares tumbled after federal regulato...
# 27  \nHeading into the first full trading week of ...
# 28  \nUS equities finally provided investors with ...
# 29  \nUS equities rose at midday as a  betterthane...
# 30  \nHeres our daily look at three charts connect...
# 31  \n UpdateJan 8 2024  For todays live markets c...
# 32  \nStock futures were lower ahead of a closelyw...
# 33  \nUS equities were mixed with the lackluster p...
# 34  \nUS equities posted gains at midday as report...
# 35  \nHeres our daily look at three charts tied to...
# 36  \n UpdateJan 5 2024  For todays live markets c...
# 37  \nIntel shares moved higher after it appointed...
# 38  \nUS equities extended early January losses on...
# 39  \nUS equities lost ground at midday on Wednesd...
# 40  \nHeres our daily look at three charts connect...
# 41  \n UpdateJan 4 2024  For todays live markets c...
# 42  \nApple shares extended losses following an an...
# 43  \nMajor US equities indexes were mixed on the ...
# 44  \nUS equities began the first day of trading i...
# 45  \n UpdateJan 3 2024  For todays live markets c...
# 46  \nHeres our daily look at three charts linked ...
# 47  \nTesla is expected to report a record number ...
# 49  \nThe last trading day of 2023 was a loser for...
# 50  \nUS equities ended the last trading day of 20...
# 51  \nUS equities were lower at midday on this las...
# 52  \nStocks finished the year on a down note All ...
# 53  \nHeres our daily look at three charts tied to...
# 54  \nNvidia is launching a slower gaming chip in ...
# 55  \nUS equities were little changed on Thursday ...
# 56  \nOrganized labor had its most active year in ...
# 57  \nUS equities traded marginally higher at midd...
# 59  \n UpdateDec 29 2023  For todays live markets ...
# 61  \nApple resumed sales of watches after an appe...
# 62  \nIt wasnt much but US equities kept their ral...
# 64  \nUS equities were little changed at midday as...
#
#                                               symbols  appears_in_vusa
# 0   [MS, GS, MS, GS, SCHW, DFS, MTB, FITB, STT, WF...             True
# 1        [CTSH, DAL, UAL, AAL, TSLA, HTZ, WRL, ELUXY]             True
# 3                [DAL, UNH, CVS, TGT, BK, T, VZ, NOC]             True
# 4                           [DOCU, BX, HTZ, TSLA, MS]             True
# 5   [VZ, CVX, MSFT, AAPL, UNH, BA, JPM, BK, NOC, L...             True
# 6   [JPM, BAC, WFC, C, DAL, XOM, BP, CVX, MARA, RI...             True
# 7                  [NFLX, PARA, WBD, CRM, VLO, EL, T]             True
# 8           [NFLX, WBD, PARA, CHK, SWN, VLO, TSLA, C]             True
# 9   [JPM, BAC, C, CRM, CVX, MSFT, AAPL, VZ, T, BA,...             True
# 10                    [COIN, PARA, TCEHY, IRBT, AMZN]             True
# 11            [MARA, RIOT, COIN, MSTR, C, GOOGL, KBH]             True
# 12                       [ISRG, META, LEN, COF, ETSY]             True
# 13                   [ISRG, LEN, AMZN, EL, GILD, AXP]             True
# 14                                   [ISRG, BLK, UNG]             True
# 15  [BLK, HD, MSFT, CRM, BA, AAPL, WBA, LEN, PHM, ...             True
# 16    [MSTR, MARA, RIOT, COIN, ISRG, TSLA, JNPR, HPE]             True
# 17                        [JPNR, HPE, ES, CTLT, ILMN]             True
# 18          [ES, BA, UAL, ALK, TSLA, JNPR, HPE, ILMN]             True
# 19                                  [JNPR, HPE, MCHP]             True
# 20  [BA, UAL, ALK, AAPL, NVDA, MRK, WMT, MSFT, CVX...             True
# 21  [BA, UAL, ALK, JNPR, HPE, CSCO, JBLU, SAVE, MT...             True
# 22               [AAL, NVDA, AMD, ANET, BA, SLB, BKR]             True
# 23    [BA, ALK, NVDA, AAPL, HPQ, BKR, SLB, JNJ, AMAM]             True
# 24               [BA, ALK, UAL, BRK.B, SWN, CHK, EQT]             True
# 25  [NVDA, BA, JPM, BAC, WFC, CRM, INTC, AAPL, NKE...             True
# 26  [BA, ALK, UAL, AAPL, NVDA, MRK, HARP, SWN, CHK...             True
# 27                             [JPM, BAC, WFC, C, BK]             True
# 28            [CTLT, LUV, AAL, VTRS, MSCI, ENPH, CAG]             True
# 29                      [STZ, COST, PLTR, ETSY, AMZN]             True
# 30                        [PSX, CVE, JBLU, SAVE, AMC]             True
# 31  [WBA, VZ, UNH, IBM, MCD, AAPL, LUV, AAL, DAL, ...             True
# 32                              [XOM, COST, TSLA, QS]             True
# 33  [APA, CPE, WBA, ETSY, AMZN, CCL, NCLH, UAL, EP...             True
# 34                     [LW, ALL, LLY, WBA, APA, AAPL]             True
# 35                   [META, SOFI, XLE, XOM, CVX, COP]             True
# 36  [MRK, AMGN, AXP, JPM, V, WBA, AAPL, CVX, MCD, ...             True
# 37               [INTC, NVDA, AMD, F, GM, META, MCHP]             True
# 38           [DG, APTV, WBA, LLY, NVO, MPC, EOG, VLO]             True
# 39                   [AAPL, SCHW, WBA, MPC, NOC, AZO]             True
# 40                 [RIVN, NCLH, XLV, MRNA, MRK, ABBV]             True
# 41  [CVX, MRK, AMGN, DIS, VZ, T, WBA, AAPL, LLY, C...             True
# 42                           [AAPL, BLMN, TSLA, ASTS]             True
# 43  [NCLH, RCL, CCL, AMD, ASML, UBER, AAPL, MRNA, ...             True
# 44            [AMD, ASML, AAPL, NCLH, MRNA, CNC, TPR]             True
# 45  [AAPL, NVDA, ASML, MRK, AMGN, UNH, JNJ, INTC, ...             True
# 46           [IQV, BGC, WGMI, MARA, CLSK, IREN, COIN]             True
# 47                [TSLA, MSTR, COIN, MARA, ASML, XOM]             True
# 49  [NVDA, META, RCL, CCL, NCLH, BLDR, UBER, FMC, ...             True
# 50                                   [UBER, WBD, BSX]             True
# 51                  [BSX, WBD, TSLA, NVDA, TMUS, UNH]             True
# 52  [UNH, CRM, INTC, MSFT, BA, JNJ, WBA, CVX, MMM,...             True
# 53                         [GOOGL, TSLA, XIACY, ATUS]             True
# 54                [NVDA, JD, GOOGL, TSLA, ARKK, COIN]             True
# 55         [MTCH, AMD, NKE, TSLA, APA, HES, EOG, MPC]             True
# 56               [T, BA, GM, F, STLA, UPS, WMT, AMZN]             True
# 57                         [AMD, MTCH, NKE, BA, PANW]             True
# 59    [XLK, PENN, AAPL, MASI, APA, EOG, COP, BA, SPR]             True
# 61                      [AAPL, SQM, TSLA, SATS, DISH]             True
# 62  [KMX, MRNA, TSLA, NWSA, MSFT, NEM, LVS, DIS, A...             True
# 64     [TSLA, NWSA, MSFT, NEM, AAPL, PARA, DIS, AMZN]             True

# %%
def get_article_links(driver):
    links = driver.find_elements(By.TAG_NAME, 'a')
    return links

# %%
def get_yahoo_news_articles_df():
    yahoo_news_driver = webdriver.Chrome(options=options)

    yahoo_news_driver.get(YAHOO_URL)
    time.sleep(1)
    yahoo_news_driver.find_element(By.CLASS_NAME, 'reject-all').click()
    actions = ActionChains(yahoo_news_driver)
    for i in range(1500):
        actions.scroll_by_amount(0, 500)
    actions.perform()
    actions.reset_actions()

    links = get_article_links(yahoo_news_driver)
    df = pd.DataFrame({'title': [link.text for link in links], 'url': [link.get_attribute('href') for link in links], 'classes': [link.get_attribute('class') for link in links]})
    yahoo_news_driver.quit()
    df = df[df['url'] \
            .str.contains('/news/') & df['classes'].str.contains('js-content-viewer')]\
            .drop_duplicates(subset='url', keep='last')\
            .reset_index(drop=True)
    return df

# %%
yahoo_news_df = get_yahoo_news_articles_df()

# %%
display(yahoo_news_df)
# Out:
#                                                  title  \
# 0    Redesigned Apple Watches not subject to import...
# 1    Boeing to add further inspections for 737 MAX\...
# 2    Microsoft co-founder Bill Gates: I am concerne...
# 3    One key reason inflation is cooling: Immigrant...
# 4            Apple could have a new problem: Uncle Sam
# ..                                                 ...
# 216  Buying the New Bitcoin ETFs? 3 Things to Keep ...
# 217  Investors bet via options that India's rupee w...
# 218           1 Growth Stock Down 81% to Buy Right Now
# 219  1 Top Growth Stock Down 80% That's a Screaming...
# 220  5 Struggling Stocks to Buy at a DiscountMotley...
#
#                                                    url  \
# 0    https://finance.yahoo.com/news/redesigned-appl...
# 1    https://finance.yahoo.com/news/boeing-add-furt...
# 2    https://finance.yahoo.com/news/microsoft-co-fo...
# 3    https://finance.yahoo.com/news/one-key-reason-...
# 4    https://finance.yahoo.com/news/apple-could-hav...
# ..                                                 ...
# 216  https://finance.yahoo.com/news/buying-bitcoin-...
# 217  https://finance.yahoo.com/news/investors-bet-v...
# 218  https://finance.yahoo.com/news/1-growth-stock-...
# 219  https://finance.yahoo.com/news/1-top-growth-st...
# 220  https://finance.yahoo.com/news/5-struggling-st...
#
#                                                classes
# 0        js-content-viewer Fw(b) Td(n) wafer-destroyed
# 1        js-content-viewer Fw(b) Td(n) wafer-destroyed
# 2    js-content-viewer Fw(b) Fz(18px) Lh(23px) Line...
# 3    js-content-viewer Fw(b) Fz(18px) Lh(23px) Line...
# 4    js-content-viewer Fw(b) Fz(18px) Lh(23px) Line...
# ..                                                 ...
# 216  js-content-viewer wafer-caas Td(n) D(ib) Va(t)...
# 217  js-content-viewer wafer-caas Fw(b) Fz(18px) Lh...
# 218  js-content-viewer wafer-caas Fw(b) Fz(18px) Lh...
# 219  js-content-viewer wafer-caas Td(n) D(ib) Va(t)...
# 220  js-content-viewer wafer-caas Td(n) D(ib) Va(t)...
#
# [221 rows x 3 columns]

# %%
def progress_bar(current, total, bar_length=20):
    fraction = current / total

    arrow = int(fraction * bar_length - 1) * '-' + '>'
    padding = int(bar_length - len(arrow)) * ' '

    ending = '\n' if current == total else '\r'

    print(f'Progress: [{arrow}{padding}] {int(fraction*100)}%', end=ending)

# %%
def scrape_articles(urls):
    articles = []
    raw_articles = []
    yahoo_driver = webdriver.Chrome(options=options)
    yahoo_driver.get(YAHOO_URL)
    yahoo_driver.find_element(By.CLASS_NAME, 'reject-all').click()

    for index, url in enumerate(urls):
        yahoo_driver.get(url)
        try:
            yahoo_driver.find_element(By.CLASS_NAME, 'collapse-button').click()
        except:
            pass
        article_p_elements = yahoo_driver.find_element(By.CLASS_NAME, 'caas-body').find_elements(By.TAG_NAME, 'p')
        article_by_paragraph = [p.text for p in article_p_elements if p.text!='']
        
        raw_article = [bs(element.get_attribute('outerHTML'), "html.parser") for element in article_p_elements]
        article = " ".join(article_by_paragraph)
        clean_article = clean_text(article)
        articles.append(clean_article)
        raw_articles.append(raw_article)
        progress_bar(index+1, len(urls))
    
        
    yahoo_driver.quit()
    
    return articles, raw_articles

# %%
yahoo_news_articles, raw_yahoo_news_articles = scrape_articles(yahoo_news_df['url'])
# Out:
# Progress: [------->            ] 42%

# %%
yahoo_news_df['article'] = yahoo_news_articles

# %%
yahoo_news_df

# %%
def combine_dfs(investopedia_df, yahoo_df):
    df1 = investopedia_df.drop(['symbols', 'appears_in_vusa'], axis=1)
    df2 = yahoo_df.drop('classes', axis=1)
    article_df = pd.concat([df1, df2])
    article_df = article_df.reset_index(drop=True)
    return article_df

# %%
df = combine_dfs(investopedia_df, yahoo_news_df)

# %%
def clean_and_tokenize(articles):
    lemmatizer = WordNetLemmatizer()
    
    tokenized_articles = []
    for article in articles:
        tokenized_article = nltk.word_tokenize(article)
        tokenized_article = [token for token in tokenized_article if token not in stopwords.words('english')]
        tokenized_article = [lemmatizer.lemmatize(token) for token in tokenized_article]
        
        tokenized_articles.append(tokenized_article)
        
    return tokenized_articles

# %%
df['tokenized_article'] = clean_and_tokenize(df['article'])

# %%
df

# %%
analyzer = SentimentIntensityAnalyzer()
scaler = MinMaxScaler()
df['positivity_score'] = [analyzer.polarity_scores(article)['pos'] for article in df['article']]
df['negativity_score'] = [analyzer.polarity_scores(article)['neg'] for article in df['article']]

# %%
df
